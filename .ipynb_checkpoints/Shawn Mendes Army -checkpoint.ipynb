# %%
#! pip install textblob

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
import pandas as pd
import pickle
from textblob import TextBlob
import re 
import string
from lyricsgenius import Genius

# %%
songAttributes = pd.read_pickle('songsWithLyrics.pkl')

# %%
clientid = 'vHqixP8O2UlLPXgkfxNqgBslNgeEjbPut_I_W8yRHQUji4Fd_XHIfbdmfWZaTo-i'
token = 'NVpYyXA_VZXEqtb_6eolyLa0D_PE9yp_0NFCat0LywlG_VDSOjcgVEuOeCiEYpu2'

genius = Genius(token)
genius.remove_section_headers = True
genius.skip_non_songs = True

def getLyrics(artistName, songName):
    result = genius.search_song(songName, artistName)
    if result is not None:
        return result.lyrics
    else:
        if "'" in artistName:
            artistName = addSlashToApostrophe(artistName) 
        if "'" in songName:
            songName = addSlashToApostrophe(songName)
        result = genius.search_song(songName, artistName)
        if result is not None:
            return result.lyrics
        return None

# %%
songAttributes.loc[songAttributes['Title'] == 'Youth (feat. Khalid)', ['Lyrics']] = getLyrics("Shawn Mendes", "Youth")
# Out:
# Searching for "Youth" by Shawn Mendes...
# Done.

# %%
songAttributes.loc[songAttributes['Title'] == 'Like To Be You (feat. Julia Michaels)', ['Lyrics']] = getLyrics("Shawn Mendes", "Like To Be You")
# Out:
# Searching for "Like To Be You" by Shawn Mendes...
# Done.

# %%
mendesArmyDF = songAttributes.loc[songAttributes.Artist == 'Shawn Mendes']

# %%
mendesArmyDF.to_pickle('mendesArmyDF.pkl')

# %%
mendesArmyDF
# Out:
#                                      Title        Artist  \
# 665                            In My Blood  Shawn Mendes
# 666                     Fallin' All In You  Shawn Mendes
# 667         Where Were You In The Morning?  Shawn Mendes
# 668                                Nervous  Shawn Mendes
# 669  Like To Be You (feat. Julia Michaels)  Shawn Mendes
# 670                          Lost In Japan  Shawn Mendes
# 671                       Particular Taste  Shawn Mendes
# 672                      Because I Had You  Shawn Mendes
# 673                                    Why  Shawn Mendes
# 674                   Youth (feat. Khalid)  Shawn Mendes
# 675                                  Queen  Shawn Mendes
# 676                        Perfectly Wrong  Shawn Mendes
# 677                                 Mutual  Shawn Mendes
# 678                      When You're Ready  Shawn Mendes
#
#                   SpotifyID    Tempo Loudness     Key isExplicit Duration  \
# 665  2QZ7WLBE8h2y1Y5Fb8RYbH  140.025   -7.321       F      False   211.36
# 666  5EYBryPOgIEPB7r5QIy6eG   92.038   -6.696  G#, Ab      False  235.747
# 667  376Gg7Oxo5C5jUWDWpVXeI   87.963   -7.472       G      False    200.6
# 668  5wxurz8J6YlyQRNnGN8zXS  121.983    -6.76       C      False  164.147
# 669  2IssBpPtHcViZL5vYQNHhA  153.766   -9.405       D      False    159.4
# 670  79esEXlqqmq0GPz0xQSZTV  105.027   -6.784   A# Bb      False    201.2
# 671  4BH9zDv1Ys6kw0j3lU1hTx  111.968   -7.122       A      False  175.573
# 672  1RRZSm4akqNyMOsPUhw4cb  203.231   -9.751       G      False   142.48
# 673  3XeqINnregzwBJNg7RyyH4  127.031   -9.247       C      False  238.173
# 674  1h0yImRPIVAjhhHeNVlTuC  100.121   -6.653  F#, Gb      False  190.867
# 675  6D8FZWtCQRtQUVT3mpjrZs   131.02   -7.254  C#, Db      False  204.693
# 676  6nat4Z7iRKWVk1qngQqI0Q   89.362  -11.748       D      False  212.773
# 677  5gW3kI83886nVV9apaFLWu   115.03   -6.697       B      False   148.36
# 678  6bNcbh4SxQDU0BHa4Dj3wx  171.479   -8.887       F      False  169.587
#
#     ReleaseDate                                             Lyrics
# 665  2018-05-25  Help me, it's like the walls are caving in\nSo...
# 666  2018-05-25  Sunrise with you on my chest\nNo blinds in the...
# 667  2018-05-25  You said, "I wanna get to know ya"\nWhy you go...
# 668  2018-05-25  I saw you on a Sunday in a café\nAnd all you d...
# 669  2018-05-25  "Don't cry" - or do\nWhatever makes you comfor...
# 670  2018-05-25  All it'd take is one flight\nWe'd be in the sa...
# 671  2018-05-25  She don't listen to a thing, 'less it feels ri...
# 672  2018-05-25  I think it's time that I be honest\nShould've ...
# 673  2018-05-25  I know a girl, she's like a curse\nWe want eac...
# 674  2018-05-25  Here I am, stuck on this couch scrolling throu...
# 675  2018-05-25  It's hard to believe\nYou don't remember me at...
# 676  2018-05-25  Taste the poison from your lips\nLately, we're...
# 677  2018-05-25  I want you close to me\nI want you close, I wa...
# 678  2018-05-25  Maybe I had too many drinks, but that's just w...

# %%
#how happy/sad are his song on this album
#different emotions in the album

#different words per emotions
#songs for each emotions
#Correlation between valence and the key, tempo, loudness
#how many of these songs includes key words about hotels (room, key, etc)

#word cloud
#most common word/least used word

# %% [markdown]
# # Polarity and Subjectivity

# %%
pol = lambda x: TextBlob(x).sentiment.polarity
sub = lambda x: TextBlob(x).sentiment.subjectivity

# %%
mendesArmyDF['Polarity'] = mendesArmyDF['Lyrics'].apply(pol)
mendesArmyDF['Subjectivity'] = mendesArmyDF['Lyrics'].apply(sub)
# Out:
# /Users/arridoarfiadi/opt/anaconda3/envs/p3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/arridoarfiadi/opt/anaconda3/envs/p3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
mendesArmyDF
# Out:
#                                      Title        Artist  \
# 665                            In My Blood  Shawn Mendes
# 666                     Fallin' All In You  Shawn Mendes
# 667         Where Were You In The Morning?  Shawn Mendes
# 668                                Nervous  Shawn Mendes
# 669  Like To Be You (feat. Julia Michaels)  Shawn Mendes
# 670                          Lost In Japan  Shawn Mendes
# 671                       Particular Taste  Shawn Mendes
# 672                      Because I Had You  Shawn Mendes
# 673                                    Why  Shawn Mendes
# 674                   Youth (feat. Khalid)  Shawn Mendes
# 675                                  Queen  Shawn Mendes
# 676                        Perfectly Wrong  Shawn Mendes
# 677                                 Mutual  Shawn Mendes
# 678                      When You're Ready  Shawn Mendes
#
#                   SpotifyID    Tempo Loudness     Key isExplicit Duration  \
# 665  2QZ7WLBE8h2y1Y5Fb8RYbH  140.025   -7.321       F      False   211.36
# 666  5EYBryPOgIEPB7r5QIy6eG   92.038   -6.696  G#, Ab      False  235.747
# 667  376Gg7Oxo5C5jUWDWpVXeI   87.963   -7.472       G      False    200.6
# 668  5wxurz8J6YlyQRNnGN8zXS  121.983    -6.76       C      False  164.147
# 669  2IssBpPtHcViZL5vYQNHhA  153.766   -9.405       D      False    159.4
# 670  79esEXlqqmq0GPz0xQSZTV  105.027   -6.784   A# Bb      False    201.2
# 671  4BH9zDv1Ys6kw0j3lU1hTx  111.968   -7.122       A      False  175.573
# 672  1RRZSm4akqNyMOsPUhw4cb  203.231   -9.751       G      False   142.48
# 673  3XeqINnregzwBJNg7RyyH4  127.031   -9.247       C      False  238.173
# 674  1h0yImRPIVAjhhHeNVlTuC  100.121   -6.653  F#, Gb      False  190.867
# 675  6D8FZWtCQRtQUVT3mpjrZs   131.02   -7.254  C#, Db      False  204.693
# 676  6nat4Z7iRKWVk1qngQqI0Q   89.362  -11.748       D      False  212.773
# 677  5gW3kI83886nVV9apaFLWu   115.03   -6.697       B      False   148.36
# 678  6bNcbh4SxQDU0BHa4Dj3wx  171.479   -8.887       F      False  169.587
#
#     ReleaseDate                                             Lyrics  Polarity  \
# 665  2018-05-25  Help me, it's like the walls are caving in\nSo... -0.006944
# 666  2018-05-25  Sunrise with you on my chest\nNo blinds in the...  0.183550
# 667  2018-05-25  You said, "I wanna get to know ya"\nWhy you go...  0.125000
# 668  2018-05-25  I saw you on a Sunday in a café\nAnd all you d... -0.004663
# 669  2018-05-25  "Don't cry" - or do\nWhatever makes you comfor... -0.106118
# 670  2018-05-25  All it'd take is one flight\nWe'd be in the sa...  0.258571
# 671  2018-05-25  She don't listen to a thing, 'less it feels ri...  0.028446
# 672  2018-05-25  I think it's time that I be honest\nShould've ...  0.303824
# 673  2018-05-25  I know a girl, she's like a curse\nWe want eac... -0.047452
# 674  2018-05-25  Here I am, stuck on this couch scrolling throu... -0.205093
# 675  2018-05-25  It's hard to believe\nYou don't remember me at...  0.108403
# 676  2018-05-25  Taste the poison from your lips\nLately, we're... -0.251852
# 677  2018-05-25  I want you close to me\nI want you close, I wa... -0.164035
# 678  2018-05-25  Maybe I had too many drinks, but that's just w...  0.085931
#
#      Subjectivity
# 665      0.670139
# 666      0.570147
# 667      0.300000
# 668      0.504365
# 669      0.553219
# 670      0.776071
# 671      0.470990
# 672      0.743038
# 673      0.449656
# 674      0.555093
# 675      0.732668
# 676      0.718519
# 677      0.456140
# 678      0.370563

# %%
! pip install matplotlib
import matplotlib.pyplot as plt
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.4.2-cp37-cp37m-macosx_10_9_x86_64.whl (7.2 MB)
#      |████████████████████████████████| 7.2 MB 3.0 MB/s eta 0:00:01     |█████████████▏                  | 2.9 MB 3.2 MB/s eta 0:00:02
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/arridoarfiadi/opt/anaconda3/envs/p3.7/lib/python3.7/site-packages (from matplotlib) (2.4.7)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp37-cp37m-macosx_10_9_x86_64.whl (61 kB)
#      |████████████████████████████████| 61 kB 17.9 MB/s eta 0:00:01
# Collecting pillow>=6.2.0
#   Downloading Pillow-8.2.0-cp37-cp37m-macosx_10_10_x86_64.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 5.5 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /Users/arridoarfiadi/opt/anaconda3/envs/p3.7/lib/python3.7/site-packages (from matplotlib) (2.8.1)
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: numpy>=1.16 in /Users/arridoarfiadi/opt/anaconda3/envs/p3.7/lib/python3.7/site-packages (from matplotlib) (1.20.2)
# Requirement already satisfied: six in /Users/arridoarfiadi/opt/anaconda3/envs/p3.7/lib/python3.7/site-packages (from cycler>=0.10->matplotlib) (1.15.0)
# Installing collected packages: pillow, kiwisolver, cycler, matplotlib
# Successfully installed cycler-0.10.0 kiwisolver-1.3.1 matplotlib-3.4.2 pillow-8.2.0

# %%
plt.rcParams['figure.figsize'] = [13,13]
plt.scatter(mendesArmyDF.Polarity, mendesArmyDF.Subjectivity,s=30)
plt.title("Sentiment Analysis")
plt.xlabel("Polarity\n\n<-- Negative(-1) ------- Positive(+1) -->")
plt.ylabel("Subjectivity\n\n<-- Facts(0) ------- Opinions(1) -->")
plt.xlim(-1,1)
plt.ylim(0,1)
for i, txt in enumerate(mendesArmyDF.Title):
    xOrigin = mendesArmyDF.loc[mendesArmyDF['Title'] == txt].Polarity + 0.005
    yOrigin = mendesArmyDF.loc[mendesArmyDF['Title'] == txt].Subjectivity + 0.005
    if txt == "Youth (feat. Khalid)":
        yOrigin += 0.009275
    if txt == "Like To Be You (feat. Julia Michaels)":
        xOrigin += 0.01
        yOrigin -= 0.01
    plt.annotate(txt, (xOrigin,yOrigin))
plt.show()

# %% [markdown]
# # Word Cloud ☁️

# %%
! pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.1.tar.gz (220 kB)
#      |████████████████████████████████| 220 kB 3.2 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.6.1 in /Users/arridoarfiadi/opt/anaconda3/envs/p3.7/lib/python3.7/site-packages (from wordcloud) (1.20.2)
# Requirement already satisfied: pillow in /Users/arridoarfiadi/opt/anaconda3/envs/p3.7/lib/python3.7/site-packages (from wordcloud) (8.2.0)
# Requirement already satisfied: matplotlib in /Users/arridoarfiadi/opt/anaconda3/envs/p3.7/lib/python3.7/site-packages (from wordcloud) (3.4.2)
# Requirement already satisfied: cycler>=0.10 in /Users/arridoarfiadi/opt/anaconda3/envs/p3.7/lib/python3.7/site-packages (from matplotlib->wordcloud) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/arridoarfiadi/opt/anaconda3/envs/p3.7/lib/python3.7/site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/arridoarfiadi/opt/anaconda3/envs/p3.7/lib/python3.7/site-packages (from matplotlib->wordcloud) (2.8.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/arridoarfiadi/opt/anaconda3/envs/p3.7/lib/python3.7/site-packages (from matplotlib->wordcloud) (2.4.7)
# Requirement already satisfied: six in /Users/arridoarfiadi/opt/anaconda3/envs/p3.7/lib/python3.7/site-packages (from cycler>=0.10->matplotlib->wordcloud) (1.15.0)
# Building wheels for collected packages: wordcloud
#   Building wheel for wordcloud (setup.py) ... done
#   Created wheel for wordcloud: filename=wordcloud-1.8.1-cp37-cp37m-macosx_10_9_x86_64.whl size=158532 sha256=5d70dcd3759c8280db4a33a69d50d0eab2b6dd3467cd9734f7477e22613284f3
#   Stored in directory: /Users/arridoarfiadi/Library/Caches/pip/wheels/f8/f6/55/6bd394c32a844a621ca0fe5dbf563c8d71d71edaf095656991
# Successfully built wordcloud
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.1

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
allWords = ""
for i, txt in enumerate(mendesArmyDF.Lyrics):
    allWords += txt
allWords = allWords.lower()
stopWords = set(STOPWORDS)
stopWords = stopWords.union(["yeah", "Oh"])
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopWords,
                min_font_size = 10).generate(allWords)
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
  
plt.show()

# %%
#todo:
#figure out lamatization and stemming
#make it pretty (this looks like 💩)
#make more stop words if needed
#corpus and document term matrix
